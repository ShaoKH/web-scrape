# %%
# import libraries
import urllib
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
## open the website of dx_label: Acne Vulgaris
## since there is an issue to soup the website url directly, I use a webdriver to simulate the browser
## for simplicity I don't use loop, but for large number of labels, can use a loop for the following steps
# use webdriver to open the website

driver = webdriver.Chrome(executable_path="/Users/shao/Desktop/Tools/chromedriver")
driver.get("https://www.dermquest.com/image-library/image-search")

# close cookie window
cookie = driver.find_element_by_xpath("//*[@id='cookiesDirectiveBox']/div/div[3]/a")
cookie.click()

# select "diagnosis"
diagnosis = driver.find_element_by_xpath("//*[@id='filter-selection']/div[1]/div[1]/ul/li[5]/a")
diagnosis.click()

# select "alphabet": A
alphabet = driver.find_element_by_xpath("//*[@id='diagnosis']/div/div[2]/div/div[1]/ul/li[1]/a")
alphabet.click()

# choose the diagnosis label as Acne Vulgaris
label = driver.find_element_by_xpath("//*[@id='alpha-A']/div/ul/li[7]/label")
label.click()

view = driver.find_element_by_xpath("//*[@id='diagnosis']/div/div[2]/div/div[2]/a")
view.click()

time.sleep(3)

itemsPerPage = driver.find_element_by_xpath("//*[@id='image-results']/div[2]/div[2]/div[1]/div[2]/div[1]/div[1]/ul/li[4]/a")
itemsPerPage.click()

time.sleep(1)

# soup the webpage
page = driver.page_source
soup = BeautifulSoup(page, "html.parser")

# %%
# extract the case id
case_id = []

for p in soup.find_all("p", {"class": "asset-name"}):
    for a in p.find_all("a"):
        href = a["href"]
        case_id.append(href)
        #print(href)
        

# creat the list of case urls
case_url = []

for i in range(len(case_id)):
    url = "https://www.dermquest.com/" + case_id[i]
    case_url.append(url)
    #print(url)
    

# choose first 100 url
case_url_100 = case_url[:100]
len(case_url_100)


print(len(case_id))
print(len(case_url))
print(len(case_url_100))
# Out:
# 128
# 128
# 100

# %%
# extract the image url, dx label and lesion label from each image page
image_url = []
dx_label = []
lesion_label = []

for url in case_url_100:
    image_id = url[-24:]
    # print(url)
    #print(image_id)
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "html.parser")
    # print(soup.prettify())
    
    # extract image url
    for li in soup.find_all("li", {"data-image-id": image_id}):
        for a in li.find_all("a", {"class": "preview-image"}):
            # print(a)
            href = a["href"]
            url = "https://www.dermquest.com" + href
            image_url.append(url)
            print(url)
            
    # extract dx label   
    for div in soup.find_all("div", {"id": "image_" + image_id}):
        table = div.find_all("table")[2]
    # print(table)
    
        td = table.find_all("td")
        dx = td[1].text.strip()
        dx_label.append(dx)
        #print(dx)
        
    
    # extract lesion label
    for div in soup.find_all("div", {"id": "image_" + image_id}):
        ul = div.find_all("ul")
        lesions = ul[0]
    
        li = lesions.find_all("li")
        
        lesion = li[0].text.strip()
        for i in range(1, len(li)):
            lesion = lesion + ", " + li[i].text.strip()
            
        lesion_label.append(lesion)
             
print(image_url)
print(dx_label)
print(lesion_label)
# Out:
# https://www.dermquest.com/imagelibrary/large/10556-P7070063.JPG
# https://www.dermquest.com/imagelibrary/large/10556-P7070060.JPG
# https://www.dermquest.com/imagelibrary/large/033072HB.JPG
# https://www.dermquest.com/imagelibrary/large/033071HB.JPG
# https://www.dermquest.com/imagelibrary/large/033070HB.JPG
B.JPG', 'https://www.dermquest.com/imagelibrary/large/032676VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032242VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033993HB.JPG', 'https://www.dermquest.com/imagelibrary/large/033316VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033043HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032664HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032529VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032290VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032086VB.JPG', 'https://www.dermquest.com/imagelibrary/large/034023HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032891VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032680VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032679VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032678VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032675VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032243VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033614VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033368VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033045VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033041HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032670HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032667HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032532HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032291VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032289VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032088VB.JPG', 'https://www.dermquest.com/imagelibrary/large/034113HB.JPG', 'https://www.dermquest.com/imagelibrary/large/034111HB.JPG', 'https://www.dermquest.com/imagelibrary/large/034107HB.JPG', 'https://www.dermquest.com/imagelibrary/large/034105HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032750HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032677VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032245VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033963HB.JPG', 'https://www.dermquest.com/imagelibrary/large/033617HB.JPG', 'https://www.dermquest.com/imagelibrary/large/033370HB.JPG', 'https://www.dermquest.com/imagelibrary/large/033367VB.JPG', 'https://www.dermquest.com/imagelibrary/large/033311HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032666HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032663HB.JPG', 'https://www.dermquest.com/imagelibrary/large/032531VB.JPG', 'https://www.dermquest.com/imagelibrary/large/032002VB.JPG', 'https://www.dermquest ...
# ['acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris', 'acne vulgaris']
# ['Comedones', 'Comedones', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Pustule / follicular', 'Pustule / follicular', 'Papule / erythematous', 'Plaque / erythematous', 'Papule / erythematous, Pustule / follicular', 'Pustule / follicular', 'Pustule / follicular, Papule / erythematous', 'Papule / erythematous, Pustule / follicular', 'Pustule / follicular, Papule / erythematous', 'Pustule / follicular', 'Pustule / follicular', 'Papule / erythematous', 'Papule / erythematous', 'Nodule', 'Papule / erythematous, Pustule / follicular', 'Pustule / follicular, Papule / erythematous', 'Plaque / erythematous', 'Papule / erythematous, Excoriation, Pustule / follicular', 'Papule / erythematous, Excoriation', 'Papule / erythematous', 'Papule / erythematous, Pustule / follicular, Erythema', 'Pustule / follicular, Erythema', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Nodule', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Pustule / follicular', 'Erosion / ulceration', 'Papule / erythematous, Pustule / follicular', 'Excoriation, Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Excoriation, Pustule / follicular', 'Excoriation, Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Excoriation, Pustule / follicular', 'Excoriation, Papule / erythematous', 'Papule / erythematous, Cyst, Scar / atrophic', 'Papule / erythematous, Erythema, Pustule / follicular', 'Papule / erythematous, Cyst, Alopecia / scarring, Scar / atrophic', 'Pustule / follicular, Erythema', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous', 'Papule / erythematous, Pustule / follicular', 'Pustule / follicular, Papule / erythematous', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Pustule / follicular', 'Erythema, Papule / erythematous, Pustule / follicular', 'Pustule / follicular, Erythema', 'Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Excoriation', 'Excoriation, Papule / erythematous, Pustule / follicular', 'Papule / erythematous, Nodule, Excoriation', 'Papule / erythematous', 'Papule / erythematous, Excoriation, Cyst', 'Papule / erythematous, Pustule / follicular, Erythema', 'Pustule / follicular, Papule / erythematous, Erythema', 'Pustule / follicular, Erythema', 'Pustule / follicular, Papule / erythematous', 'Papule / erythematous, Pustule / follicular', 'Nodule, Papule / erythematous', 'Papule / erythematous, Excoriation', 'Pustule / follicular, Erythema', 'Pustule / follicular, Papule / erythematous, Erythema', 'Papule / erythematous, Pustule / follicular', 'Pustule / follicular, Papule / erythematous, Erythema', 'Pustule / follicular, Erythema', 'Pustule / follicular, Papule / erythematous', 'Excoriation, Papule / erythematous', 'Papule / erythematous, Excoriation', 'Excoriation, Papule / erythematous', 'Pustule / follicular', 'Pustule / follicular, Erythema', 'Pustule / follicular', 'Papule / erythematous, Pustule / follicular, Erythema', 'Pustule / follicular, Papule / erythematous', 'Papule / erythematous, Pustule / follicular', 'Nodule, Papule / erythematous', 'Papule / erythematous, Pustule / follicular', 'Pustule / follicular, Papule / erythematous', 'Pustule / follicular, Erythema', 'Papule / erythematous, Erythema, Comedones, Pustule / follicular', 'Papule / erythematous, Pustule / follicular, Comedones, Erythema', 'Papule / erythematous, Erythema, Comedones, Pustule / follicular', 'Papule / erythematous, Comedones, Erythema', 'Papule / erythematous, Erythema, Comedones', 'Papule / erythematous, Comedones, Erythema, Pustule / follicular', 'Papule / erythematous, Pustule / follicular, Erythema, Comedones', 'Nodule, Papule / erythematous, Comedones, Erythema, Pustule / follicular', 'Papule / erythem ...

# %%
# create fisrt data sheet
d1 = {'image url': image_url, 'dx_label': dx_label, 'lesion_label': lesion_label}
df1 = pd.DataFrame(data=d1,  columns={'image url', 'dx_label', 'lesion_label'})
print(df1.shape)
# Out:
# (100, 3)

# %%
## open the website of dx_label: Dermatofibroma
# use webdriver to open the website
driver = webdriver.Chrome(executable_path="/Users/shao/Desktop/Tools/chromedriver")
driver.get("https://www.dermquest.com/image-library/image-search")

# close cookie window
cookie = driver.find_element_by_xpath("//*[@id='cookiesDirectiveBox']/div/div[3]/a")
cookie.click()

# select "diagnosis"
diagnosis = driver.find_element_by_xpath("//*[@id='filter-selection']/div[1]/div[1]/ul/li[5]/a")
diagnosis.click()

# select "alphabet": D
alphabet = driver.find_element_by_xpath("//*[@id='diagnosis']/div/div[2]/div/div[1]/ul/li[4]/a")
alphabet.click()

# choose the diagnosis label as Dermatofibroma
label = driver.find_element_by_xpath("//*[@id='alpha-D']/div/ul/li[5]/label")
label.click()

view = driver.find_element_by_xpath("//*[@id='diagnosis']/div/div[2]/div/div[2]/a")
view.click()

time.sleep(3)

itemsPerPage = driver.find_element_by_xpath("//*[@id='image-results']/div[2]/div[2]/div[1]/div[2]/div[1]/div[1]/ul/li[4]/a")
itemsPerPage.click()

time.sleep(1)

# soup the webpage
page = driver.page_source
soup = BeautifulSoup(page, "html.parser")

# %%
# extract the case id
case_id = []

for p in soup.find_all("p", {"class": "asset-name"}):
    for a in p.find_all("a"):
        href = a["href"]
        case_id.append(href)
        # print(href)

print(len(case_id))
    

# creat the list of case urls
case_url = []

for i in range(len(case_id)):
    url = "https://www.dermquest.com/" + case_id[i]
    case_url.append(url)
    # print(url)

print(len(case_url))



# choose first 100 url
case_url_100 = case_url[:100]
print(len(case_url_100))
# Out:
# 128
# 128
# 100

# %%
# extract the image url, dx label and lesion label from each image page
image_url = []
dx_label = []
lesion_label = []

for url in case_url_100:
    image_id = url[-24:]
    # print(url)
    #print(image_id)
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "html.parser")
    # print(soup.prettify())
    
    # extract image url
    for li in soup.find_all("li", {"data-image-id": image_id}):
        for a in li.find_all("a", {"class": "preview-image"}):
            # print(a)
            href = a["href"]
            url = "https://www.dermquest.com" + href
            image_url.append(url)
            print(url)
            
    # extract dx label   
    for div in soup.find_all("div", {"id": "image_" + image_id}):
        table = div.find_all("table")[2]
    # print(table)
    
        td = table.find_all("td")
        dx = td[1].text.strip()
        dx_label.append(dx)
        #print(dx)
        
    
    # extract lesion label
    for div in soup.find_all("div", {"id": "image_" + image_id}):
        ul = div.find_all("ul")
        lesions = ul[0]
    
        li = lesions.find_all("li")
        
        lesion = li[0].text.strip()
        for i in range(1, len(li)):
            lesion = lesion + ", " + li[i].text.strip()
            
        lesion_label.append(lesion)
        
        
print(image_url)
print(dx_label)
print(lesion_label)
# Out:
# https://www.dermquest.com/imagelibrary/large/023180HB.JPG
# https://www.dermquest.com/imagelibrary/large/023179HB.JPG
# https://www.dermquest.com/imagelibrary/large/023178HB.JPG
# https://www.dermquest.com/imagelibrary/large/023187HB.JPG
# https://www.dermquest.com/imagelibrary/large/023184HB.JPG
# https://www.dermquest.com/imagelibrary/large/023185HB.JPG
# https://www.dermquest.com/imagelibrary/large/023351HB.JPG
# https://www.dermquest.com/imagelibrary/large/023339HB.JPG
# https://www.dermquest.com/imagelibrary/large/023334HB.JPG
# https://www.dermquest.com/imagelibrary/large/023323HB.JPG
# https://www.dermquest.com/imagelibrary/large/023322HB.JPG
# https://www.dermquest.com/imagelibrary/large/023319HB.JPG
# https://www.dermquest.com/imagelibrary/large/023318HB.JPG
# https://www.dermquest.com/imagelibrary/large/023298VB.JPG
# https://www.dermquest.com/imagelibrary/large/023297VB.JPG
# https://www.dermquest.com/imagelibrary/large/023220HB.JPG
# https://www.dermquest.com/imagelibrary/large/045902HB.JPG
# https://www.dermquest.com/imagelibrary/large/045901HB.JPG
# https://www.dermquest.com/imagelibrary/large/045899HB.JPG
# https://www.dermquest.com/imagelibrary/large/045240HB.JPG
# https://www.dermquest.com/imagelibrary/large/023360HB.JPG
# https://www.dermquest.com/imagelibrary/large/023359HB.JPG
# https://www.dermquest.com/imagelibrary/large/023326HB.JPG
# https://www.dermquest.com/imagelibrary/large/023315HB.JPG
# https://www.dermquest.com/imagelibrary/large/023304HB.JPG
# https://www.dermquest.com/imagelibrary/large/023291HB.JPG
# https://www.dermquest.com/imagelibrary/large/023269HB.JPG
# https://www.dermquest.com/imagelibrary/large/023260HB.JPG
# https://www.dermquest.com/imagelibrary/large/023197HB.JPG
# https://www.dermquest.com/imagelibrary/large/023157VB.JPG
# https://www.dermquest.com/imagelibrary/large/023148HB.JPG
# https://www.dermquest.com/imagelibrary/large/023146HB.JPG
# https://www.dermquest.com/imagelibrary/large/023130HB.JPG
# https://www.dermquest.com/imagelibrary/large/023089HB.JPG
# https://www.dermquest.com/imagelibrary/large/023086HB.JPG
# https://www.dermquest.com/imagelibrary/large/023012HB.JPG
# https://www.dermquest.com/imagelibrary/large/044920HB.JPG
# https://www.dermquest.com/imagelibrary/large/000227VB.JPG
# https://www.dermquest.com/imagelibrary/large/023276VB.JPG
# https://www.dermquest.com/imagelibrary/large/023274VB.JPG
# https://www.dermquest.com/imagelibrary/large/023273VB.JPG
# https://www.dermquest.com/imagelibrary/large/023272HB.JPG
# https://www.dermquest.com/imagelibrary/large/023246HB.JPG
# https://www.dermquest.com/imagelibrary/large/023245HB.JPG
# https://www.dermquest.com/imagelibrary/large/023175VB.JPG
# https://www.dermquest.com/imagelibrary/large/023136HB.JPG
# https://www.dermquest.com/imagelibrary/large/023059HB.JPG
# ['https://www.dermquest.com/imagelibrary/large/023180HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023179HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023178HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023187HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023184HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023185HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023351HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023339HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023334HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023323HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023322HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023319HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023318HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023298VB.JPG', 'https://www.dermquest.com/imagelibrary/large/023297VB.JPG', 'https://www.dermquest.com/imagelibrary/large/023220HB.JPG', 'https://www.dermquest.com/imagelibrary/large/045902HB.JPG', 'https://www.dermquest.com/imagelibrary/large/045901HB.JPG', 'https://www.dermquest.com/imagelibrary/large/045899HB.JPG', 'https://www.dermquest.com/imagelibrary/large/045240HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023360HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023359HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023326HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023315HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023304HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023291HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023269HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023260HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023197HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023157VB.JPG', 'https://www.dermquest.com/imagelibrary/large/023148HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023146HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023130HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023089HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023086HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023012HB.JPG', 'https://www.dermquest.com/imagelibrary/large/044920HB.JPG', 'https://www.dermquest.com/imagelibrary/large/000227VB.JPG', 'https://www.dermquest.com/imagelibrary/large/023342HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023280HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023252VB.JPG', 'https://www.dermquest.com/imagelibrary/large/023250HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023244HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023236HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023174VB.JPG', 'https://www.dermquest.com/imagelibrary/large/023155HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023143HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023138HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023133HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023066HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023062HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023050HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023048HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023020HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023003HB.JPG', 'https://www.dermquest.com/imagelibrary/large/022975HB.JPG', 'https://www.dermquest.com/imagelibrary/large/022951HB.JPG', 'https://www.dermquest.com/imagelibrary/large/022945VB.JPG', 'https://www.dermquest.com/imagelibrary/large/019780HB.JPG', 'https://www.dermquest.com/imagelibrary/large/000228HB.JPG', 'https://www.dermquest.com/imagelibrary/large/000224HB.JPG', 'https://www.dermquest.com/imagelibrary/large/000223HB.JPG', 'https://www.dermquest.com/imagelibrary/large/000214HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023347HB.JPG', 'https://www.dermquest.com/imagelibrary/large/023337VB.JPG', 'https://www.dermquest.com/imageli ...
# ['dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma', 'dermatofibroma']
# ['Nodule, Papule / erythematous', 'Nodule, Papule / erythematous', 'Papule / erythematous, Nodule', 'Papule / hyperpigmented, Nodule', 'Nodule, Papule / hyperpigmented', 'Nodule, Papule / hyperpigmented', 'Nodule, Papule / hyperpigmented, Tumour', 'Papule / erythematous, Erythema', 'Nodule, Tumour, Erythema', 'Nodule', 'Nodule', 'Papule / hyperpigmented, Nodule, Tumour', 'Nodule, Papule / hyperpigmented, Tumour', 'Nodule, Tumour, Erythema', 'Nodule, Erythema, Tumour', 'Nodule, Erythema', 'Papule / erythematous, Nodule, Erythema, Tumour', 'Nodule, Papule / erythematous, Tumour, Erythema', 'Nodule, Papule / hyperpigmented, Tumour', 'Nodule, Erythema', 'Nodule, Erythema', 'Nodule, Erythema', 'Nodule, Erythema', 'Papule / erythematous', 'Plaque / erythematous, Nodule', 'Papule / skin color', 'Plaque / erythemato-squamous, Tumour, Squames / scales, Erythema', 'Nodule / hyperpigmented', 'Nodule / hyperpigmented', 'Papule / erythematous, Nodule, Erythema, Tumour', 'Papule / erythematous', 'Papule / erythematous', 'Nodule, Papule / erythematous, Tumour, Erythema', 'Papule / erythemato-squamous, Tumour, Squames / scales', 'Nodule, Papule / erythematous, Tumour, Erythema', 'Nodule / erythematous', 'Nodule, Papule / erythematous, Erythema, Tumour', 'Nodule, Papule / erythematous, Tumour, Erythema', 'Papule / erythematous', 'Macule / hyperpigmented', 'Nodule, Erythema', 'Atrophy, Macule / erythematous', 'Erosion / ulceration, Papule / erythematous', 'Papule / hyperpigmented', 'Nodule, Erosion / ulceration, Crust', 'Nodule', 'Nodule, Squames / scales, Erythema', 'Nodule, Papule / hyperpigmented, Tumour', 'Squames / scales, Nodule / hyperpigmented', 'Nodule, Hyperkeratosis, Erythema, Tumour', 'Nodule, Tumour, Erythema, Hyperkeratosis', 'Nodule, Erosion / ulceration, Squames / scales', 'Erosion / ulceration, Nodule, Squames / scales', 'Macule / erythematous', 'Nodule, Erythema, Tumour', 'Nodule, Erythema', 'Nodule, Erythema', 'Nodule', 'Squames / scales, Nodule / hyperpigmented', 'Nodule, Squames / scales, Erythema', 'Nodule, Papule / hyperpigmented, Tumour', 'Crust, Nodule', 'Papule / hyperpigmented', 'Papule / hyperpigmented, Tumour', 'Nodule, Erythema', 'Nodule, Tumour, Erythema', 'Nodule, Erythema, Tumour', 'Papule / erythematous, Tumour, Erythema', 'Nodule, Erythema, Tumour', 'Nodule, Erythema', 'Erythema, Papule / erythematous, Tumour', 'Nodule, Papule / erythematous, Erythema, Tumour', 'Papule / erythematous, Nodule, Tumour, Erythema', 'Nodule, Papule / erythematous, Erythema, Tumour', 'Nodule', 'Papule / skin color', 'Plaque / erythemato-squamous, Erythema, Tumour, Squames / scales', 'Crust, Nodule / hyperpigmented', 'Nodule, Papule / hyperpigmented', 'Papule / erythematous, Tumour, Erythema', 'Nodule, Papule / erythematous, Erythema, Tumour', 'Papule / erythematous, Nodule, Tumour, Erythema', 'Nodule, Papule / erythematous, Erythema, Tumour', 'Nodule', 'Nodule, Papule / erythematous, Tumour, Erythema', 'Nodule, Atrophy, Plaque / erythematous', 'Nodule, Erythema, Squames / scales', 'Papule / hyperpigmented', 'Nodule, Tumour, Erythema', 'Nodule / hyperpigmented', 'Anetoderma, Nodule, Papule / hyperpigmented', 'Tumour', 'Tumour', 'Tumour', 'Papule / erythematous', 'Papule / erythematous', 'Papule / erythematous', 'Nodule, Erosion / ulceration, Crust', 'Nodule, Papule / hyperpigmented, Tumour', 'Nodule']

# %%
# create second data sheet, merge two sheets into one and export to csv file
d2 = {'image url': image_url, 'dx_label': dx_label, 'lesion_label': lesion_label}
df2 = pd.DataFrame(data=d2,  columns={'image url', 'dx_label', 'lesion_label'})
print(df2.shape)
df = [df1, df2]
sheet = pd.concat(df)
sheet = sheet[['image url', 'dx_label', 'lesion_label']]
print(sheet.shape)
sheet.to_csv('sheet_complete.csv', index=False)
# Out:
# (100, 3)
# (200, 3)
